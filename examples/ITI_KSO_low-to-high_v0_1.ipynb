# %% [markdown]
# # **Instrument to Instrument (ITI) translation: Kanzelhoehe Solar Observatory (KSO)**

# %% [markdown]
# ## Read The Docs
# For more information about the tool and background of the individual case studies see:
#
# [iti-documentation.rtfd.io](https://iti-documentation.readthedocs.io/en/latest/)

# %%
import os
os.getcwd()
# Out:
# '/home/jhpan/ITI/InstrumentToInstrument/examples'

# %%
import sys
sys.executable
# Out:
# '/opt/anaconda3/bin/python'

# %% [markdown]
# ## Installation

# %%
# !pip install git+https://github.com/spaceml-org/InstrumentToInstrument.git@development
# !pip install lightning
# !pip install sunpy_soar
# !pip install sunpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/spaceml-org/InstrumentToInstrument.git@development
#   Cloning https://github.com/spaceml-org/InstrumentToInstrument.git (to revision development) to /tmp/pip-req-build-rqmlg1qt
#   Running command git clone --filter=blob:none --quiet https://github.com/spaceml-org/InstrumentToInstrument.git /tmp/pip-req-build-rqmlg1qt
#   Running command git checkout -b development --track origin/development
#   Switched to a new branch 'development'
#   Branch 'development' set up to track remote branch 'development' from 'origin'.
#   Resolved https://github.com/spaceml-org/InstrumentToInstrument.git to commit 47749c8fce60fdd33aaf3de400b732e1d6f3ed68
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8 in /home/jhpan/.local/lib/python3.11/site-packages (from itipy==0.1) (2.5.1)
# Requirement already satisfied: sunpy>=2.0 in /home/jhpan/.local/lib/python3.11/site-packages (from itipy==0.1) (6.1.1)
# Requirement already satisfied: scikit-image in /opt/anaconda3/lib/python3.11/site-packages (from itipy==0.1) (0.20.0)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.11/site-packages (from itipy==0.1) (1.3.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from itipy==0.1) (4.65.0)
# Requirement already satisfied: numpy in /home/jhpan/.local/lib/python3.11/site-packages (from itipy==0.1) (1.26.4)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.11/site-packages (from itipy==0.1) (3.7.2)
# Requirement already satisfied: astropy in /home/jhpan/.local/lib/python3.11/site-packages (from itipy==0.1) (7.0.1)
# Collecting aiapy (from itipy==0.1)
#   Obtaining dependency information for aiapy from https://files.pythonhosted.org/packages/77/86/443dda992c76b8b742df106847dc06b359e01ca61d740c3ae86405d0e2b7/aiapy-0.10.1-py3-none-any.whl.metadata
#   Downloading aiapy-0.10.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting drms (from itipy==0.1)
#   Obtaining dependency information for drms from https://files.pythonhosted.org/packages/ae/97/a2442c67f409732d4a23e7ba37e819cffa913616f2d18ffb6ff4a317c7f9/drms-0.9.0-py3-none-any.whl.metadata
#   Downloading drms-0.9.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: jupyter in /opt/anaconda3/lib/python3.11/site-packages (from itipy==0.1) (1.0.0)
# Collecting sunpy_soar (from itipy==0.1)
#   Obtaining dependency information for sunpy_soar from https://files.pythonhosted.org/packages/62/a7/48464896fd97a7125fea5860199b173f5e708e24068e6f862578d82b8f98/sunpy_soar-1.11.1-py3-none-any.whl.metadata
#   Downloading sunpy_soar-1.11.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting lightning (from itipy==0.1)
#   Obtaining dependency information for lightning from https://files.pythonhosted.org/packages/9e/1b/67201d693a575e8a086831710f33e697fab66166223f792e459ef2b84934/lightning-2.5.1.post0-py3-none-any.whl.metadata
#   Downloading lightning-2.5.1.post0-py3-none-any.whl.metadata (39 kB)
# Collecting google (from itipy==0.1)
#   Obtaining dependency information for google from https://files.pythonhosted.org/packages/ac/35/17c9141c4ae21e9a29a43acdfd848e3e468a810517f862cad07977bf8fe9/google-3.0.0-py2.py3-none-any.whl.metadata
#   Downloading google-3.0.0-py2.py3-none-any.whl.metadata (627 bytes)
# Collecting google-cloud-storage (from itipy==0.1)
#   Obtaining dependency information for google-cloud-storage from https://files.pythonhosted.org/packages/13/b8/c99c965659f45efa73080477c49ffddf7b9aecb00806be8422560bb5b824/google_cloud_storage-3.1.0-py2.py3-none-any.whl.metadata
#   Downloading google_cloud_storage-3.1.0-py2.py3-none-any.whl.metadata (12 kB)
# Collecting wandb (from itipy==0.1)
#   Obtaining dependency information for wandb from https://files.pythonhosted.org/packages/88/c9/41b8bdb493e5eda32b502bc1cc49d539335a92cacaf0ef304d7dae0240aa/wandb-0.20.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading wandb-0.20.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting pytorch_fid (from itipy==0.1)
#   Obtaining dependency information for pytorch_fid from https://files.pythonhosted.org/packages/dd/2b/e8c875b9380f34c70d4b5d98deaaa8bcac4922388efad08a72cf129118ee/pytorch_fid-0.3.0-py3-none-any.whl.metadata
#   Downloading pytorch_fid-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: packaging>=23.0 in /opt/anaconda3/lib/python3.11/site-packages (from sunpy>=2.0->itipy==0.1) (23.1)
# Requirement already satisfied: parfive[ftp]>=2.0.0 in /home/jhpan/.local/lib/python3.11/site-packages (from sunpy>=2.0->itipy==0.1) (2.1.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /home/jhpan/.local/lib/python3.11/site-packages (from sunpy>=2.0->itipy==0.1) (2.0.1.5)
# Requirement already satisfied: requests>=2.28.0 in /opt/anaconda3/lib/python3.11/site-packages (from sunpy>=2.0->itipy==0.1) (2.31.0)
# Requirement already satisfied: fsspec>=2023.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from sunpy>=2.0->itipy==0.1) (2023.4.0)
# Requirement already satisfied: astropy-iers-data>=0.2025.1.31.12.41.4 in /home/jhpan/.local/lib/python3.11/site-packages (from astropy->itipy==0.1) (0.2025.3.3.0.34.45)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from astropy->itipy==0.1) (6.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (4.12.2)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/jhpan/.local/lib/python3.11/site-packages (from torch>=1.8->itipy==0.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from sympy==1.13.1->torch>=1.8->itipy==0.1) (1.3.0)
# Requirement already satisfied: pandas>=1.5.1 in /opt/anaconda3/lib/python3.11/site-packages (from drms->itipy==0.1) (2.0.3)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.11/site-packages (from google->itipy==0.1) (4.12.2)
# Collecting google-auth<3.0dev,>=2.26.1 (from google-cloud-storage->itipy==0.1)
#   Obtaining dependency information for google-auth<3.0dev,>=2.26.1 from https://files.pythonhosted.org/packages/17/63/b19553b658a1692443c62bd07e5868adaa0ad746a0751ba62c59568cd45b/google_auth-2.40.3-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-api-core<3.0.0dev,>=2.15.0 (from google-cloud-storage->itipy==0.1)
#   Obtaining dependency information for google-api-core<3.0.0dev,>=2.15.0 from https://files.pythonhosted.org/packages/14/4b/ead00905132820b623732b175d66354e9d3e69fcf2a5dcdab780664e7896/google_api_core-2.25.1-py3-none-any.whl.metadata
#   Downloading google_api_core-2.25.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-cloud-core<3.0dev,>=2.4.2 (from google-cloud-storage->itipy==0.1)
#   Obtaining dependency information for google-cloud-core<3.0dev,>=2.4.2 from https://files.pythonhosted.org/packages/40/86/bda7241a8da2d28a754aad2ba0f6776e35b67e37c36ae0c45d49370f1014/google_cloud_core-2.4.3-py2.py3-none-any.whl.metadata
#   Downloading google_cloud_core-2.4.3-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media>=2.7.2 (from google-cloud-storage->itipy==0.1)
#   Obtaining dependency information for google-resumable-media>=2.7.2 from https://files.pythonhosted.org/packages/82/35/b8d3baf8c46695858cb9d8835a53baa1eeb9906ddaf2f728a5f5b640fd1e/google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata
#   Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage->itipy==0.1)
#   Obtaining dependency information for google-crc32c<2.0dev,>=1.0 from https://files.pythonhosted.org/packages/c9/16/a3842c2cf591093b111d4a5e2bfb478ac6692d02f1b386d2a33283a19dc9/google_crc32c-1.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading google_crc32c-1.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: notebook in /opt/anaconda3/lib/python3.11/site-packages (from jupyter->itipy==0.1) (6.5.4)
# Requirement already satisfied: qtconsole in /opt/anaconda3/lib/python3.11/site-packages (from jupyter->itipy==0.1) (5.4.2)
# Requirement already satisfied: jupyter-console in /opt/anaconda3/lib/python3.11/site-packages (from jupyter->itipy==0.1) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/anaconda3/lib/python3.11/site-packages (from jupyter->itipy==0.1) (6.5.4)
# Requirement already satisfied: ipykernel in /opt/anaconda3/lib/python3.11/site-packages (from jupyter->itipy==0.1) (6.25.0)
# Requirement already satisfied: ipywidgets in /opt/anaconda3/lib/python3.11/site-packages (from jupyter->itipy==0.1) (8.0.4)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning->itipy==0.1)
#   Obtaining dependency information for lightning-utilities<2.0,>=0.10.0 from https://files.pythonhosted.org/packages/1a/c1/31b3184cba7b257a4a3b5ca5b88b9204ccb7aa02fe3c992280899293ed54/lightning_utilities-0.14.3-py3-none-any.whl.metadata
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning->itipy==0.1)
#   Obtaining dependency information for torchmetrics<3.0,>=0.7.0 from https://files.pythonhosted.org/packages/6f/f2/bed7da46003c26ed44fc7fa3ecc98a84216f0d4758e5e6a3693754d490d9/torchmetrics-1.7.3-py3-none-any.whl.metadata
#   Downloading torchmetrics-1.7.3-py3-none-any.whl.metadata (21 kB)
# Collecting pytorch-lightning (from lightning->itipy==0.1)
#   Obtaining dependency information for pytorch-lightning from https://files.pythonhosted.org/packages/de/a9/e14821cfaf08e8d78185cca0477c9d3a62bafe1b4b530100f7b66bb1f7bb/pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata
#   Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->itipy==0.1) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->itipy==0.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->itipy==0.1) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->itipy==0.1) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->itipy==0.1) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->itipy==0.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->itipy==0.1) (2.8.2)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.11/site-packages (from pytorch_fid->itipy==0.1) (1.11.1)
# Requirement already satisfied: torchvision>=0.2.2 in /home/jhpan/.local/lib/python3.11/site-packages (from pytorch_fid->itipy==0.1) (0.20.1)
# Requirement already satisfied: imageio>=2.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-image->itipy==0.1) (2.31.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-image->itipy==0.1) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-image->itipy==0.1) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-image->itipy==0.1) (0.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn->itipy==0.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn->itipy==0.1) (2.2.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/anaconda3/lib/python3.11/site-packages (from wandb->itipy==0.1) (8.0.4)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb->itipy==0.1)
#   Obtaining dependency information for gitpython!=3.1.29,>=1.0.0 from https://files.pythonhosted.org/packages/1d/9a/4114a9057db2f1462d5c8f8390ab7383925fe1ac012eaa42402ad65c2963/GitPython-3.1.44-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /opt/anaconda3/lib/python3.11/site-packages (from wandb->itipy==0.1) (3.10.0)
# Collecting protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 (from wandb->itipy==0.1)
#   Obtaining dependency information for protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 from https://files.pythonhosted.org/packages/fa/b1/b59d405d64d31999244643d88c45c8241c58f17cc887e73bcb90602327f8/protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata
#   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: psutil>=5.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from wandb->itipy==0.1) (5.9.0)
# Requirement already satisfied: pydantic<3 in /opt/anaconda3/lib/python3.11/site-packages (from wandb->itipy==0.1) (1.10.8)
# Collecting sentry-sdk>=2.0.0 (from wandb->itipy==0.1)
#   Obtaining dependency information for sentry-sdk>=2.0.0 from https://files.pythonhosted.org/packages/5a/99/31ac6faaae33ea698086692638f58d14f121162a8db0039e68e94135e7f1/sentry_sdk-2.30.0-py2.py3-none-any.whl.metadata
#   Downloading sentry_sdk-2.30.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting setproctitle (from wandb->itipy==0.1)
#   Obtaining dependency information for setproctitle from https://files.pythonhosted.org/packages/cc/41/fbf57ec52f4f0776193bd94334a841f0bc9d17e745f89c7790f336420c65/setproctitle-1.3.6-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading setproctitle-1.3.6-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/lib/python3.11/site-packages (from fsspec>=2023.3.0->sunpy>=2.0->itipy==0.1) (3.8.5)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb->itipy==0.1)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/a0/61/5c78b91c3143ed5c14207f463aecfc8f9dbb5092fb2869baf37c273b2705/gitdb-4.0.12-py3-none-any.whl.metadata
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->itipy==0.1)
#   Obtaining dependency information for googleapis-common-protos<2.0.0,>=1.56.2 from https://files.pythonhosted.org/packages/86/f1/62a193f0227cf15a920390abe675f386dec35f7ae3ffe6da582d3ade42c7/googleapis_common_protos-1.70.0-py3-none-any.whl.metadata
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->itipy==0.1)
#   Obtaining dependency information for proto-plus<2.0.0,>=1.22.3 from https://files.pythonhosted.org/packages/4e/6d/280c4c2ce28b1593a19ad5239c8b826871fc6ec275c21afc8e1820108039/proto_plus-1.26.1-py3-none-any.whl.metadata
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->itipy==0.1)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/72/76/20fa66124dbe6be5cafeb312ece67de6b61dd91a0247d1ea13db4ebb33c2/cachetools-5.5.2-py3-none-any.whl.metadata
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->itipy==0.1) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->itipy==0.1)
#   Obtaining dependency information for rsa<5,>=3.1.4 from https://files.pythonhosted.org/packages/64/8d/0133e4eb4beed9e425d9a98ed6e081a55d195481b7632472be1af08d2f6b/rsa-4.9.1-py3-none-any.whl.metadata
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning->itipy==0.1) (68.0.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.5.1->drms->itipy==0.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.5.1->drms->itipy==0.1) (2023.3)
# Requirement already satisfied: aioftp>=0.17.1 in /home/jhpan/.local/lib/python3.11/site-packages (from parfive[ftp]>=2.0.0->sunpy>=2.0->itipy==0.1) (0.24.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->itipy==0.1) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.0->sunpy>=2.0->itipy==0.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.0->sunpy>=2.0->itipy==0.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.0->sunpy>=2.0->itipy==0.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.0->sunpy>=2.0->itipy==0.1) (2024.2.2)
# Collecting mpl-animators>=1.0.0 (from sunpy>=2.0->itipy==0.1)
#   Obtaining dependency information for mpl-animators>=1.0.0 from https://files.pythonhosted.org/packages/60/56/8ad4bf78320ce8b37ccc5d74be9c0669a3264e881ccf2f9439cc9c1a01ca/mpl_animators-1.2.3-py3-none-any.whl.metadata
#   Downloading mpl_animators-1.2.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: reproject>=0.10.0 in /home/jhpan/.local/lib/python3.11/site-packages (from sunpy>=2.0->itipy==0.1) (0.14.1)
# Collecting zeep>=4.1.0 (from sunpy>=2.0->itipy==0.1)
#   Obtaining dependency information for zeep>=4.1.0 from https://files.pythonhosted.org/packages/46/92/8a76eeccb5c176ea3de3965598b6fcd10dc9d72a560e59919b52845327ed/zeep-4.3.1-py3-none-any.whl.metadata
#   Downloading zeep-4.3.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->google->itipy==0.1) (2.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->itipy==0.1) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->itipy==0.1) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->itipy==0.1) (8.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->itipy==0.1) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->itipy==0.1) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->itipy==0.1) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->itipy==0.1) (1.5.6)
# Requirement already satisfied: pyzmq>=20 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->itipy==0.1) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->itipy==0.1) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->itipy==0.1) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipywidgets->jupyter->itipy==0.1) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipywidgets->jupyter->itipy==0.1) (3.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.8->itipy==0.1) (2.1.1)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-console->jupyter->itipy==0.1) (3.0.36)
# Requirement already satisfied: pygments in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-console->jupyter->itipy==0.1) (2.15.1)
# Requirement already satisfied: lxml in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->itipy==0.1) (4.9.3)
# Requirement already satisfied: bleach in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->itipy==0.1) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->itipy==0.1) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->itipy==0.1) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->itipy==0.1) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->itipy==0.1) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->itipy==0.1) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->itipy==0.1) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->itipy==0.1) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->itipy==0.1) (1.2.1)
# Requirement already satisfied: argon2-cffi in /opt/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->itipy==0.1) (21.3.0)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->itipy==0.1) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->itipy==0.1) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->itipy==0.1) (0.17.1)
# Requirement already satisfied: prometheus-client in /opt/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->itipy==0.1) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->itipy==0.1) (0.5.5)
# Requirement already satisfied: qtpy>=2.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from qtconsole->jupyter->itipy==0.1) (2.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.3.0->sunpy>=2.0->itipy==0.1) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.3.0->sunpy>=2.0->itipy==0.1) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.3.0->sunpy>=2.0->itipy==0.1) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.3.0->sunpy>=2.0->itipy==0.1) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.3.0->sunpy>=2.0->itipy==0.1) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.3.0->sunpy>=2.0->itipy==0.1) (1.2.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->itipy==0.1)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/04/be/d09147ad1ec7934636ad912901c5fd7667e1c858e19d355237db0d0cd5e4/smmap-5.0.2-py3-none-any.whl.metadata
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: backcall in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->itipy==0.1) (0.2.0)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->itipy==0.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->itipy==0.1) (0.18.1)
# Requirement already satisfied: pickleshare in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->itipy==0.1) (0.7.5)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->itipy==0.1) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->itipy==0.1) (4.8.0)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter->itipy==0.1) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter->itipy==0.1) (0.2.2)
# Requirement already satisfied: fastjsonschema in /opt/anaconda3/lib/python3.11/site-packages (from nbformat>=5.1->nbconvert->jupyter->itipy==0.1) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/lib/python3.11/site-packages (from nbformat>=5.1->nbconvert->jupyter->itipy==0.1) (4.17.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.11/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->itipy==0.1) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage->itipy==0.1) (0.4.8)
# Requirement already satisfied: astropy-healpix>=1.0 in /home/jhpan/.local/lib/python3.11/site-packages (from reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (1.1.2)
# Requirement already satisfied: dask[array]>=2021.8 in /opt/anaconda3/lib/python3.11/site-packages (from reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (2023.6.0)
# Requirement already satisfied: cloudpickle in /opt/anaconda3/lib/python3.11/site-packages (from reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (2.2.1)
# Requirement already satisfied: zarr in /home/jhpan/.local/lib/python3.11/site-packages (from reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (3.0.4)
# Requirement already satisfied: ptyprocess in /opt/anaconda3/lib/python3.11/site-packages (from terminado>=0.8.3->notebook->jupyter->itipy==0.1) (0.7.0)
# Collecting isodate>=0.5.4 (from zeep>=4.1.0->sunpy>=2.0->itipy==0.1)
#   Obtaining dependency information for isodate>=0.5.4 from https://files.pythonhosted.org/packages/15/aa/0aca39a37d3c7eb941ba736ede56d689e7be91cab5d9ca846bde3999eba6/isodate-0.7.2-py3-none-any.whl.metadata
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests-toolbelt>=0.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from zeep>=4.1.0->sunpy>=2.0->itipy==0.1) (1.0.0)
# Requirement already satisfied: requests-file>=1.5.1 in /opt/anaconda3/lib/python3.11/site-packages (from zeep>=4.1.0->sunpy>=2.0->itipy==0.1) (1.5.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/lib/python3.11/site-packages (from argon2-cffi->notebook->jupyter->itipy==0.1) (21.2.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.11/site-packages (from bleach->nbconvert->jupyter->itipy==0.1) (0.5.1)
# Requirement already satisfied: partd>=1.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from dask[array]>=2021.8->reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (1.4.0)
# Requirement already satisfied: toolz>=0.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from dask[array]>=2021.8->reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from dask[array]>=2021.8->reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (6.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->itipy==0.1) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->itipy==0.1) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->itipy==0.1) (3.5.0)
# Requirement already satisfied: websocket-client in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->itipy==0.1) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->itipy==0.1) (1.15.1)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->itipy==0.1) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->itipy==0.1) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->itipy==0.1) (0.2.2)
# Requirement already satisfied: donfig>=0.8 in /home/jhpan/.local/lib/python3.11/site-packages (from zarr->reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (0.8.1.post1)
# Requirement already satisfied: numcodecs[crc32c]>=0.14 in /home/jhpan/.local/lib/python3.11/site-packages (from zarr->reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (0.15.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.11/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->itipy==0.1) (1.2.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->itipy==0.1) (2.21)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask[array]>=2021.8->reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (3.11.0)
# Requirement already satisfied: deprecated in /home/jhpan/.local/lib/python3.11/site-packages (from numcodecs[crc32c]>=0.14->zarr->reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (1.2.18)
# Requirement already satisfied: crc32c>=2.7 in /home/jhpan/.local/lib/python3.11/site-packages (from numcodecs[crc32c]>=0.14->zarr->reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (2.7.1)
# Requirement already satisfied: locket in /opt/anaconda3/lib/python3.11/site-packages (from partd>=1.2.0->dask[array]>=2021.8->reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (1.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/anaconda3/lib/python3.11/site-packages (from deprecated->numcodecs[crc32c]>=0.14->zarr->reproject>=0.10.0->sunpy>=2.0->itipy==0.1) (1.14.1)
# Downloading aiapy-0.10.1-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading drms-0.9.0-py3-none-any.whl (37 kB)
# Downloading google-3.0.0-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 2.4 MB/s eta 0:00:00
# Downloading google_cloud_storage-3.1.0-py2.py3-none-any.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.9/174.9 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Downloading lightning-2.5.1.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 5.0 MB/s eta 0:00:00a 0:00:01
# Downloading pytorch_fid-0.3.0-py3-none-any.whl (15 kB)
# Downloading sunpy_soar-1.11.1-py3-none-any.whl (19 kB)
# Downloading wandb-0.20.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 23.0 MB/s eta 0:00:0000:0100:01
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.6/207.6 kB 34.5 MB/s eta 0:00:00
# Downloading google_api_core-2.25.1-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.8/160.8 kB 29.0 MB/s eta 0:00:00
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.1/216.1 kB 35.2 MB/s eta 0:00:00
# Downloading google_cloud_core-2.4.3-py2.py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32 kB)
# Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 18.5 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.1/321.1 kB 42.7 MB/s eta 0:00:00
# Downloading sentry_sdk-2.30.0-py2.py3-none-any.whl (343 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.1/343.1 kB 43.4 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.3-py3-none-any.whl (962 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 962.6/962.6 kB 50.5 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 53.9 MB/s eta 0:00:00
# Downloading setproctitle-1.3.6-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 15.9 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.5/294.5 kB 42.9 MB/s eta 0:00:00
# Downloading mpl_animators-1.2.3-py3-none-any.whl (35 kB)
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 13.7 MB/s eta 0:00:00
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading zeep-4.3.1-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 22.7 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Building wheels for collected packages: itipy
#   Building wheel for itipy (setup.py) ... done
#   Created wheel for itipy: filename=itipy-0.1-py3-none-any.whl size=173252 sha256=ef902635dbc9432c5e7c6515e22fd3e7d20439a9e83437b47b988880bc9949ca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qzc58ri5/wheels/4f/25/79/f739b11f30bf673aec0b160a78d0fb95eeac65e7f43a01bcdb
# Successfully built itipy
# Installing collected packages: smmap, setproctitle, sentry-sdk, rsa, protobuf, lightning-utilities, isodate, google-crc32c, cachetools, proto-plus, googleapis-common-protos, google-resumable-media, google-auth, google, gitdb, zeep, mpl-animators, google-api-core, gitpython, drms, wandb, torchmetrics, google-cloud-core, pytorch-lightning, pytorch_fid, google-cloud-storage, lightning, sunpy_soar, aiapy, itipy
#   WARNING: The scripts pyrsa-decrypt, pyrsa-encrypt, pyrsa-keygen, pyrsa-priv2pub, pyrsa-sign and pyrsa-verify are installed in '/home/jhpan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts wandb and wb are installed in '/home/jhpan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pytorch-fid is installed in '/home/jhpan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script fabric is installed in '/home/jhpan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed aiapy-0.10.1 cachetools-5.5.2 drms-0.9.0 gitdb-4.0.12 gitpython-3.1.44 google-3.0.0 google-api-core-2.25.1 google-auth-2.40.3 google-cloud-core-2.4.3 google-cloud-storage-3.1.0 google-crc32c-1.7.1 google-resumable-media-2.7.2 googleapis-common-protos-1.70.0 isodate-0.7.2 itipy-0.1 lightning-2.5.1.post0 lightning-utilities-0.14.3 mpl-animators-1.2.3 proto-plus-1.26.1 protobuf-6.31.1 pytorch-lightning-2.5.1.post0 pytorch_fid-0.3.0 rsa-4.9.1 sentry-sdk-2.30.0 setproctitle-1.3.6 smmap-5.0.2 sunpy_soar-1.11.1 torchmetrics-1.7.3 wandb-0.20.1 zeep-4.3.1
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lightning in /home/jhpan/.local/lib/python3.11/site-packages (2.5.1.post0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /opt/anaconda3/lib/python3.11/site-packages (from lightning) (6.0)
# Requirement already satisfied: fsspec[http]<2026.0,>=2022.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from lightning) (2023.4.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /home/jhpan/.local/lib/python3.11/site-packages (from lightning) (0.14.3)
# Requirement already satisfied: packaging<25.0,>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from lightning) (23.1)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /home/jhpan/.local/lib/python3.11/site-packages (from lightning) (2.5.1)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /home/jhpan/.local/lib/python3.11/site-packages (from lightning) (1.7.3)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /opt/anaconda3/lib/python3.11/site-packages (from lightning) (4.65.0)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /home/jhpan/.local/lib/python3.11/site-packages (from lightning) (4.12.2)
# Requirement already satisfied: pytorch-lightning in /home/jhpan/.local/lib/python3.11/site-packages (from lightning) (2.5.1.post0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/lib/python3.11/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (3.8.5)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (68.0.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (3.9.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/jhpan/.local/lib/python3.11/site-packages (from torch<4.0,>=2.1.0->lightning) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from sympy==1.13.1->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in /home/jhpan/.local/lib/python3.11/site-packages (from torchmetrics<3.0,>=0.7.0->lightning) (1.26.4)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests->fsspec[http]<2026.0,>=2022.5.0->lightning) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests->fsspec[http]<2026.0,>=2022.5.0->lightning) (2024.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sunpy_soar in /home/jhpan/.local/lib/python3.11/site-packages (1.11.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from sunpy_soar) (3.7.2)
# Requirement already satisfied: astropy>=5.3.0 in /home/jhpan/.local/lib/python3.11/site-packages (from sunpy_soar) (7.0.1)
# Requirement already satisfied: sunpy[net]>=6.0.0 in /home/jhpan/.local/lib/python3.11/site-packages (from sunpy_soar) (6.1.1)
# Requirement already satisfied: requests>=2.28.0 in /opt/anaconda3/lib/python3.11/site-packages (from sunpy_soar) (2.31.0)
# Requirement already satisfied: numpy>=1.23.2 in /home/jhpan/.local/lib/python3.11/site-packages (from astropy>=5.3.0->sunpy_soar) (1.26.4)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /home/jhpan/.local/lib/python3.11/site-packages (from astropy>=5.3.0->sunpy_soar) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.1.31.12.41.4 in /home/jhpan/.local/lib/python3.11/site-packages (from astropy>=5.3.0->sunpy_soar) (0.2025.3.3.0.34.45)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from astropy>=5.3.0->sunpy_soar) (6.0)
# Requirement already satisfied: packaging>=22.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from astropy>=5.3.0->sunpy_soar) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.6.0->sunpy_soar) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.6.0->sunpy_soar) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.6.0->sunpy_soar) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.6.0->sunpy_soar) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.6.0->sunpy_soar) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.6.0->sunpy_soar) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.6.0->sunpy_soar) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.0->sunpy_soar) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.0->sunpy_soar) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.0->sunpy_soar) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.0->sunpy_soar) (2024.2.2)
# Requirement already satisfied: parfive[ftp]>=2.0.0 in /home/jhpan/.local/lib/python3.11/site-packages (from sunpy[net]>=6.0.0->sunpy_soar) (2.1.0)
# Requirement already satisfied: fsspec>=2023.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from sunpy[net]>=6.0.0->sunpy_soar) (2023.4.0)
# Requirement already satisfied: beautifulsoup4>=4.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from sunpy[net]>=6.0.0->sunpy_soar) (4.12.2)
# Requirement already satisfied: drms>=0.7.1 in /home/jhpan/.local/lib/python3.11/site-packages (from sunpy[net]>=6.0.0->sunpy_soar) (0.9.0)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/anaconda3/lib/python3.11/site-packages (from sunpy[net]>=6.0.0->sunpy_soar) (4.65.0)
# Requirement already satisfied: zeep>=4.1.0 in /home/jhpan/.local/lib/python3.11/site-packages (from sunpy[net]>=6.0.0->sunpy_soar) (4.3.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.11.0->sunpy[net]>=6.0.0->sunpy_soar) (2.4)
# Requirement already satisfied: pandas>=1.5.1 in /opt/anaconda3/lib/python3.11/site-packages (from drms>=0.7.1->sunpy[net]>=6.0.0->sunpy_soar) (2.0.3)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.11/site-packages (from parfive[ftp]>=2.0.0->sunpy[net]>=6.0.0->sunpy_soar) (3.8.5)
# Requirement already satisfied: aioftp>=0.17.1 in /home/jhpan/.local/lib/python3.11/site-packages (from parfive[ftp]>=2.0.0->sunpy[net]>=6.0.0->sunpy_soar) (0.24.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->sunpy_soar) (1.16.0)
# Requirement already satisfied: attrs>=17.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from zeep>=4.1.0->sunpy[net]>=6.0.0->sunpy_soar) (22.1.0)
# Requirement already satisfied: isodate>=0.5.4 in /home/jhpan/.local/lib/python3.11/site-packages (from zeep>=4.1.0->sunpy[net]>=6.0.0->sunpy_soar) (0.7.2)
# Requirement already satisfied: lxml>=4.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from zeep>=4.1.0->sunpy[net]>=6.0.0->sunpy_soar) (4.9.3)
# Requirement already satisfied: platformdirs>=1.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from zeep>=4.1.0->sunpy[net]>=6.0.0->sunpy_soar) (3.10.0)
# Requirement already satisfied: requests-toolbelt>=0.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from zeep>=4.1.0->sunpy[net]>=6.0.0->sunpy_soar) (1.0.0)
# Requirement already satisfied: requests-file>=1.5.1 in /opt/anaconda3/lib/python3.11/site-packages (from zeep>=4.1.0->sunpy[net]>=6.0.0->sunpy_soar) (1.5.1)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.11/site-packages (from zeep>=4.1.0->sunpy[net]>=6.0.0->sunpy_soar) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.5.1->drms>=0.7.1->sunpy[net]>=6.0.0->sunpy_soar) (2023.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=2.0.0->sunpy[net]>=6.0.0->sunpy_soar) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=2.0.0->sunpy[net]>=6.0.0->sunpy_soar) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=2.0.0->sunpy[net]>=6.0.0->sunpy_soar) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=2.0.0->sunpy[net]>=6.0.0->sunpy_soar) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=2.0.0->sunpy[net]>=6.0.0->sunpy_soar) (1.2.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sunpy in /home/jhpan/.local/lib/python3.11/site-packages (6.1.1)
# Requirement already satisfied: astropy>=6.0.0 in /home/jhpan/.local/lib/python3.11/site-packages (from sunpy) (7.0.1)
# Requirement already satisfied: numpy>=1.24.0 in /home/jhpan/.local/lib/python3.11/site-packages (from sunpy) (1.26.4)
# Requirement already satisfied: packaging>=23.0 in /opt/anaconda3/lib/python3.11/site-packages (from sunpy) (23.1)
# Requirement already satisfied: parfive[ftp]>=2.0.0 in /home/jhpan/.local/lib/python3.11/site-packages (from sunpy) (2.1.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /home/jhpan/.local/lib/python3.11/site-packages (from sunpy) (2.0.1.5)
# Requirement already satisfied: requests>=2.28.0 in /opt/anaconda3/lib/python3.11/site-packages (from sunpy) (2.31.0)
# Requirement already satisfied: fsspec>=2023.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from sunpy) (2023.4.0)
# Requirement already satisfied: astropy-iers-data>=0.2025.1.31.12.41.4 in /home/jhpan/.local/lib/python3.11/site-packages (from astropy>=6.0.0->sunpy) (0.2025.3.3.0.34.45)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from astropy>=6.0.0->sunpy) (6.0)
# Requirement already satisfied: tqdm>=4.27.0 in /opt/anaconda3/lib/python3.11/site-packages (from parfive[ftp]>=2.0.0->sunpy) (4.65.0)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.11/site-packages (from parfive[ftp]>=2.0.0->sunpy) (3.8.5)
# Requirement already satisfied: aioftp>=0.17.1 in /home/jhpan/.local/lib/python3.11/site-packages (from parfive[ftp]>=2.0.0->sunpy) (0.24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.0->sunpy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.0->sunpy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.0->sunpy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.0->sunpy) (2024.2.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=2.0.0->sunpy) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=2.0.0->sunpy) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=2.0.0->sunpy) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=2.0.0->sunpy) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=2.0.0->sunpy) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=2.0.0->sunpy) (1.2.0)

# %% [markdown]
# ## Imports

# %%
import sys, types, itipy            # 先正常导入 itipy
sys.modules['iti'] = types.ModuleType('iti')   # 创建假模块名
sys.modules['iti'].__dict__.update(itipy.__dict__)

# %%
from itipy.translate import *
import matplotlib.pyplot as plt
from urllib.request import urlretrieve
import warnings
warnings.filterwarnings('ignore')
os.makedirs('samples', exist_ok=True)

base_path = os.getcwd()

# %% [markdown]
# We select a random observation with quality degradataions from the KSO data archive.

# %% [markdown]
# # KSO degraded to corrected observation

# %% [markdown]
# ## Download data

# %%
kso_path = 'samples/kso.fits'

# %%
urlretrieve('http://cesar.kso.ac.at/halpha3a/2013/20130111/processed/kanz_halph_fi_20130111_084223.fts.gz', kso_path)
# Out:
# ('samples/kso.fits', <http.client.HTTPMessage at 0x79dfff130a50>)

# %% [markdown]
# The Kanzelhohe Solar Observatory (KSO) provides ground-based Halpha observations at high-cadence. The effect of atmospheric degradations can be mitiageted by ITI. This notebook demonstrates the translation from distorted Halpha observations to observations showing no atmospheric distortions.

# %% [markdown]
# We initialize the translator class for the ITI translation.

# %%
translator = KSOLowToHigh(model_path='./kso_low_to_high_v0_2.pt')

# %% [markdown]
# For ground-based observations we first apply a correction of the center-to-limb varaition. In order to compare the pre-processed observations to the ITI enhanced observations we can request the numpy arrays by ``setting return_arrays=True``.

# %%
(_, kso, iti_kso) = list(translator.translate([kso_path], return_arrays=True))[0]

# %% [markdown]
# We assert the correction of the extended cloud at full-disk level.

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 10))
axs[0].imshow(kso[0], cmap='gray', origin='lower', )
axs[0].set_axis_off()
axs[0].set_title('Original')
axs[1].imshow(iti_kso[0], cmap='gray', origin='lower')
axs[1].set_axis_off()
axs[1].set_title('ITI')
plt.show()

# %% [markdown]
# # KSO film-to-CCD

# %% [markdown]
# KSO provides Halpha observations dating back to 1973. We can use ITI to restore the scanned photographic film observations in the qualtiy of the recent instrument.

# %% [markdown]
# We start by downloading a random observation from the archive (note that some observations are too strong degraded to recover them with ITI).

# %%
film_path = 'samples/film.fits'
urlretrieve('http://cesar.kso.ac.at/hafilma/1980/19800110/processed/1240457_Ha19800110_131058.fts.gz', film_path)
# Out:
# ('samples/film.fits', <http.client.HTTPMessage at 0x7ff6e692b160>)

# %% [markdown]
# We initialize the translator class an perform the translation

# %%
translator = KSOFilmToCCD()
(_, film, iti_film) = list(translator.translate([film_path], return_arrays=True))[0]

# %% [markdown]
# We compare both images. Note that the solar limb is not always correctly detected, which can lead to wrong interpretations by ITI.

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 10))
axs[0].imshow(film[0], cmap='gray', origin='lower')
axs[0].set_axis_off()
axs[0].set_title('Original')
axs[1].imshow(iti_film[0], cmap='gray', origin='lower')
axs[1].set_axis_off()
axs[1].set_title('ITI')
plt.show()
